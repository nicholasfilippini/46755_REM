# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
# Case 1 ATCs nominal for every zone ( prices are equal for every zone)

# %%
case_1 = [6.02, 6.02, 6.02, 6.02, 6.02, 6.02, 6.02, 6.02, 6.02, 6.02, 6.02, 6.02, 6.02, 6.02, 10.52, 10.52, 11.62, 13.32, 13.32, 13.51, 13.48, 13.52, 13.32, 12.59
         ]

# %%
# plot m_node1, m_node5, m_node10, m_node16, m_node23
plt.plot(case_1, marker='x', linestyle='-', label='Case 1', color = 'red', drawstyle='steps')
#plt.plot(m_node5_congested, linestyle='-', label='Congested - Node 5 ', color = 'blue', drawstyle='steps', alpha=0.75)
#plt.plot(m_node13_congested, linestyle='-', label='Congested - Node 13', color = 'green', drawstyle='steps', alpha=0.75)
#plt.plot(m_node22_congested, linestyle='-', label='Congested - Node 22', color = 'orange', drawstyle='steps', alpha=0.75)
plt.legend(title="Scenario")
plt.xlabel('Time (hours)', fontweight='bold')
plt.ylabel('Market clearing price ($/MWh)', fontweight='bold')
plt.xticks(np.arange(0, 24, 3), ('12am', '3am', '6am', '9am', '12pm', '3pm', '6pm', '9pm'))
plt.grid()
plt.show()

# %%
#case 2  ATC down to 20%

# %%
case_2_zone1 = [6.02,
6.02,
6.02,
6.02,
6.02,
6.02,
6.02,
6.02,
6.02,
6.02,
6.02,
6.02,
6.02,
6.02,
10.52,
10.52,
11.62,
13.32,
13.32,
13.51,
13.48,
13.52,
13.32,
12.59,
         ]

# %%
case_2_zone2 = [6.02,
6.02,
6.02,
6.02,
6.02,
6.02,
6.02,
6.02,
6.02,
6.02,
6.02,
6.02,
6.02,
6.02,
10.52,
10.89,
11.62,
13.32,
13.32,
13.51,
13.48,
13.52,
13.32,
12.59]

# %%
case_2_zone3 =[6.02,
6.02,
6.02,
6.02,
6.02,
6.02,
6.02,
6.02,
6.02,
6.02,
6.02,
6.02,
6.02,
6.02,
10.52,
10.89,
11.62,
13.32,
13.32,
13.51,
13.48,
13.52,
13.32,
12.59]

# %%
# plot m_node1, m_node5, m_node10, m_node16, m_node23
plt.plot(case_1, marker='x', linestyle='-', label='Case 1', color = 'red', drawstyle='steps')
plt.plot(case_2_zone1, linestyle='-', label='Zone 1 ', color = 'blue', drawstyle='steps', alpha=0.75)
plt.plot(case_2_zone2, linestyle='-', label='Zone 2', color = 'green', drawstyle='steps', alpha=0.75)
plt.plot(case_2_zone3, linestyle='-', label='Zone 3', color = 'orange', drawstyle='steps', alpha=0.75)
plt.legend(title="Scenario")
plt.xlabel('Time (hours)', fontweight='bold')
plt.ylabel('Market clearing price ($/MWh)', fontweight='bold')
plt.xticks(np.arange(0, 24, 3), ('12am', '3am', '6am', '9am', '12pm', '3pm', '6pm', '9pm'))
plt.grid()
plt.show()

# %%
#case 3  ATC scale down to 5%

# %%
case3_zone1 = [6.02,
6.02,
6.02,
6.02,
5.47,
5.47,
5.47,
6.02,
6.02,
6.02,
6.02,
6.02,
6.02,
6.02,
6.02,
7.0,
7.0,
10.52,
10.52,
10.52,
10.52,
10.52,
10.52,
10.52]

# %%
case3_zone2 =[ 6.02,
6.02,
6.02,
6.02,
6.02,
6.02,
6.02,
6.02,
6.02,
6.02,
6.02,
6.02,
6.02,
6.02,
6.02,
11.14,
13.32,
13.32,
15.99,
16.63,
16.59,
13.52,
13.32,
13.32]

# %%
case3_zone3 = [10.89,
10.52,
10.52,
10.52,
8.27,
8.26,
10.49,
10.52,
10.52,
10.52,
10.52,
10.52,
10.52,
10.74,
10.89,
11.14,
13.32,
13.32,
15.99,
16.63,
16.59,
16.64,
16.38,
13.32]

# %%
# plot m_node1, m_node5, m_node10, m_node16, m_node23
plt.plot(case_1, marker='x', linestyle='-', label='Case 1', color = 'red', drawstyle='steps')
plt.plot(case3_zone1, linestyle='-', label='Zone 1 ', color = 'blue', drawstyle='steps', alpha=0.75)
plt.plot(case3_zone2, linestyle='-', label='Zone 2', color = 'green', drawstyle='steps', alpha=0.75)
plt.plot(case3_zone3, linestyle='-', label='Zone 3', color = 'orange', drawstyle='steps', alpha=0.75)
plt.legend(title="Scenario")
plt.xlabel('Time (hours)', fontweight='bold')
plt.ylabel('Market clearing price ($/MWh)', fontweight='bold')
plt.xticks(np.arange(0, 24, 3), ('12am', '3am', '6am', '9am', '12pm', '3pm', '6pm', '9pm'))
plt.grid()
plt.show()

# %%
#case 4  ATC scale down to 1%  assymetricaly and maximum availability between 2 and 3

# %%
case4_zone1 = [ 6.02,
6.02,
6.02,
5.47,
5.47,
5.47,
5.47,
5.47,
5.47,
5.47,
5.47,
6.02,
6.02,
6.02,
6.02,
7.0,
7.0,
7.0,
10.52,
10.52,
7.0,
7.0,
7.0,
7.0]

# %%
case4_zone2 = [10.52,
10.52,
10.52,
10.52,
10.18,
10.17,
10.49,
10.52,
10.52,
10.52,
10.52,
10.52,
10.52,
10.52,
10.89,
13.32,
13.32,
15.11,
15.99,
16.63,
16.59,
16.64,
16.38,
13.32]

# %%
case4_zone3 = [10.52,
10.52,
10.52,
10.52,
10.18,
10.17,
10.49,
10.52,
10.52,
10.52,
10.52,
10.52,
10.52,
10.52,
10.89,
13.32,
13.32,
15.11,
15.99,
16.63,
16.59,
16.64,
16.38,
13.32]

# %%
# plot m_node1, m_node5, m_node10, m_node16, m_node23
plt.plot(case_1, marker='x', linestyle='-', label='Case 1', color = 'red', drawstyle='steps')
plt.plot(case4_zone1, linestyle='-', label='Zone 1 ', color = 'blue', drawstyle='steps', alpha=0.75)
plt.plot(case4_zone2, linestyle='-', label='Zone 2', color = 'green', drawstyle='steps', alpha=0.75)
plt.plot(case4_zone3, linestyle='-', label='Zone 3', color = 'orange', drawstyle='steps', alpha=0.75)
plt.legend(title="Scenario")
plt.xlabel('Time (hours)', fontweight='bold')
plt.ylabel('Market clearing price ($/MWh)', fontweight='bold')
plt.xticks(np.arange(0, 24, 3), ('12am', '3am', '6am', '9am', '12pm', '3pm', '6pm', '9pm'))
plt.grid()
plt.show()
