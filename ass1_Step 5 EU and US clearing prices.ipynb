# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
# Differencies between European and US model clearing prcices

# %%
EU_mp = [7.0,
        6.02, 6.02, 5.47, 5.47, 5.47, 5.47, 5.47, 5.47, 5.47, 5.47, 6.02, 6.02, 7.0, 10.52, 10.89, 11.62, 15.11, 15.99, 16.63, 16.59, 16.64, 16.38, 13.32]
US_mp = [7.0, 7.0, 6.02, 5.47, 5.47, 5.47, 5.47, 5.47, 5.47, 6.02, 6.02, 6.02, 6.02, 7.0, 10.52, 10.89, 11.62, 12.28, 15.99, 16.63, 13.48, 13.52, 13.31, 12.59]

# %%
# plot market clearing prices for US and EU model 
plt.plot(EU_mp, linestyle='-', label='EU_ market price', color = 'red', drawstyle='steps')
plt.plot(US_mp, linestyle='-', label='US_ market price', color = 'blue', drawstyle='steps', alpha=0.75)
plt.legend(title="Market clearing prices")
plt.xlabel('Time (hours)', fontweight='bold')
plt.ylabel('Market clearing price ($/MWh)', fontweight='bold')
plt.xticks(np.arange(0, 24, 3), ('12am', '3am', '6am', '9am', '12pm', '3pm', '6pm', '9pm'))
plt.grid()
plt.show()
